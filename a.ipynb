# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
a1 = pd.read_csv('model_history/part_a/sequential_1_12.csv')
a2 = pd.read_csv('model_history/part_a/sequential_21.csv')
a3 = pd.read_csv('model_history/part_a/sequential_12.csv')
a4 = pd.read_csv('model_history/part_a/sequential_10.csv')

# %%
b1 = pd.read_csv('model_history/part_b/sequential_3_19.csv')
b2 = pd.read_csv('model_history/part_b/sequential_16.csv')
b3 = pd.read_csv('model_history/part_b/sequential_15.csv')
b4 = pd.read_csv('model_history/part_b/sequential_10.csv')

# %%
def myplot(a1, a2, a3, a4):
    a1['loss'].plot(title="Average training error vs epochs", xlabel='Epoch', ylabel='Loss', label='Architectue 1')
    a2['loss'].plot(title="Average training error vs epochs", xlabel='Epoch', ylabel='Loss', label='Architectue 2')
    a3['loss'].plot(title="Average training error vs epochs", xlabel='Epoch', ylabel='Loss', label='Architectue 3')
    a4['loss'].plot(title="Average training error vs epochs", xlabel='Epoch', ylabel='Loss', label='Architectue 4')
    plt.legend()
    plt.show()

# %%
myplot(a1, a2, a3, a4)

# %%
myplot(b1, b2, b3, b4)
